# %%
x = 2

# %%
x
# Out:
# 2

# %%
import pandas as pd

# %%
aaa = pd.read_csv(r'C:\Users\jgian\Desktop\STUDIO_INDIVIDUALE\STUDIOO\02.DATAANALYSIS\PYTHON\01.Pandas\tatauranga-umanga-maori-statistics-on-maori-businesses-march-2024-quarter.csv')

# %%
aaa
# Out:
#                                            Table_Number  \
# 0                                                     1
# 1                                                     1
# 2                                                     1
# 3                                                     1
# 4                                                     1
# ...                                                 ...
# 1387  7,"Goods exports, by Maori authorities and all...
# 1388  7,"Goods exports, by Maori authorities and all...
# 1389  7,"Goods exports, by Maori authorities and all...
# 1390  7,"Goods exports, by Maori authorities and all...
# 1391  7,"Goods exports, by Maori authorities and all...
#
#                                      Table_Name Table_Sub_Name  \
# 0     Sales and purchases by Maori authorities     Total sales
# 1     Sales and purchases by Maori authorities     Total sales
# 2     Sales and purchases by Maori authorities     Total sales
# ...
